# %%
#Load the package libraries needed
import pandas as pd
import os
import numpy as np
import csv

from pandas import ExcelWriter
from pandas import ExcelFile

# %%
#Import Roads_InfoAboutEachLRP as the data file is easier to manipulate
df_roadsinfo = pd.read_csv('Roads_InfoAboutEachLRP.csv')

# %%
#Small overview of the file to see if it is imported correctly
df_roadsinfo.head()
# Out:
#   road  chainage     lrp        lat        lon       type  \
# 0   N1     0.000    LRPS  23.706028  90.443333     Others
# 1   N1     0.814   LRPSa  23.702917  90.450417    Culvert
# 2   N1     0.822   LRPSb  23.702778  90.450472  CrossRoad
# 3   N1     1.000  LRP001  23.702139  90.451972     KmPost
# 4   N1     2.000  LRP002  23.697889  90.460583     KmPost
#
#                                                 name
# 0  Start of Road  after Jatrabari Flyover infront...
# 1                                        Box Culvert
# 2                            Intersection with Z1101
# 3                                    Km post missing
# 4                                    Km post missing

# %%
#Use chainage to create two new columns (for longitude and latitude) which gives the absolute difference between them
#Grouped by road name so that it will not create a difference between different roads
#Output made in absolute values
#Fill missing values with 0
df_roadsinfo["lat_diff"] = df_roadsinfo.groupby("road")["lat"].diff().abs().fillna(0)
df_roadsinfo["lon_diff"] = df_roadsinfo.groupby("road")["lon"].diff().abs().fillna(0)

df_roadsinfo.head()
# Out:
#   road  chainage     lrp        lat        lon       type  \
# 0   N1     0.000    LRPS  23.706028  90.443333     Others
# 1   N1     0.814   LRPSa  23.702917  90.450417    Culvert
# 2   N1     0.822   LRPSb  23.702778  90.450472  CrossRoad
# 3   N1     1.000  LRP001  23.702139  90.451972     KmPost
# 4   N1     2.000  LRP002  23.697889  90.460583     KmPost
#
#                                                 name  lat_diff  lon_diff
# 0  Start of Road  after Jatrabari Flyover infront...  0.000000  0.000000
# 1                                        Box Culvert  0.003111  0.007084
# 2                            Intersection with Z1101  0.000139  0.000056
# 3                                    Km post missing  0.000639  0.001500
# 4                                    Km post missing  0.004250  0.008611

# %%
#Use the lat and lon differences to create boundary limits based per road
#The boundary is set to 1.96 the standard deviation
std_lat = df_roadsinfo.groupby(["road"])["lat_diff"].std()*1.96
std_lon = df_roadsinfo.groupby(["road"])["lon_diff"].std()*1.96

# %%
#Check how it looks (the boundary differences per road)
std_lat
# Out:
# road
# N1       0.170943
# N101     0.008024
# N102     0.406995
# N103     0.005190
# N104     0.008686
# N105     0.005488
# N106     0.003181
# N107     0.003846
# N108     0.002942
# N109     0.003896
# N110     0.001802
# N111     0.291729
# N112     0.005093
# N119     0.003328
# N120     0.004822
# N123     0.004815
# N124     0.009817
# N125     0.005681
# N126     0.005681
# N127     0.001296
# N128     0.002804
# N129     0.003525
# N2       0.522193
# N203     0.001580
# N204     0.056393
# N205     0.005865
# N206     0.002118
# N207     0.224025
# N208     0.008400
# N209     0.002571
#            ...
# Z8606    0.002070
# Z8607    0.460692
# Z8611    0.003418
# Z8699    0.005600
# Z8701    0.005443
# Z8702    0.002823
# Z8703    0.001148
# Z8704    0.003928
# Z8705    0.002868
# Z8706    0.001403
# Z8708    0.004945
# Z8709    0.002186
# Z8713    0.003417
# Z8716    0.002875
# Z8717    0.235083
# Z8740    0.000873
# Z8750    0.001827
# Z8803    0.005408
# Z8804    0.006576
# Z8806    0.011021
# Z8810    0.005458
# Z8814    0.051855
# Z8815    0.002934
# Z8905    0.021887
# Z8909    0.001741
# Z8910    0.006141
# Z8913    0.005232
# Z8915    0.002815
# Z8916    0.562930
# Z8943    0.602093
# Name: lat_diff, Length: 877, dtype: float64

# %%
 def delete_outliers(row):
    """This function checks if the differences between LRPs are in the boundary. 
    If it falls outside the boundaries it will return delete. This is only to identify the outliers """
    
    #Set the boundaries depending on the road
    boundary_lat = std_lat.get(row.road)
    boundary_lon = std_lon.get(row.road)
    
    #Check if the absolute differences are inside the boundary, if not return delete showing that the point might be wrong
    if df_roadsinfo.iloc[row.name, 7] > boundary_lat:
        return "delete"
    if df_roadsinfo.iloc[row.name, 8] > boundary_lon:
        return "delete"

# %%
#Apply the function "delete_outliers"
df_roadsinfo["delete_c"] = df_roadsinfo.apply(delete_outliers, axis = 1)

# %%
#See if it works
df_roadsinfo
# Out:
#         road  chainage      lrp        lat        lon            type  \
# 0         N1     0.000     LRPS  23.706028  90.443333          Others
# 1         N1     0.814    LRPSa  23.702917  90.450417         Culvert
# 2         N1     0.822    LRPSb  23.702778  90.450472       CrossRoad
# 3         N1     1.000   LRP001  23.702139  90.451972          KmPost
# 4         N1     2.000   LRP002  23.697889  90.460583          KmPost
# 5         N1     2.130  LRP002a  23.697361  90.461667         Culvert
# 6         N1     3.000   LRP003  23.693833  90.469138          KmPost
# 7         N1     4.000   LRP004  23.693611  90.478777          KmPost
# 8         N1     4.175  LRP004a  23.693805  90.480527  SideRoad,Right
# 9         N1     5.000   LRP005  23.694750  90.488500          KmPost
# 10        N1     6.000   LRP006  23.695916  90.498194          KmPost
# 11        N1     7.000   LRP007  23.697333  90.507750          KmPost
# 12        N1     7.181  LRP007a  23.697916  90.509278       CrossRoad
# 13        N1     8.000   LRP008  23.702056  90.515722          KmPost
# 14        N1     8.011  LRP008a  23.702111  90.515778          Bridge
# 15        N1     8.429  LRP008b  23.704583  90.518833          Bridge
# 16        N1     8.503   LRP009  23.705028  90.519333          KmPost
# 17        N1     8.763  LRP009a  23.706083  90.521527   SideRoad,Left
# 18        N1     9.503   LRP010  23.702528  90.527388          KmPost
# 19        N1     9.615  LRP010a  23.701528  90.528194         Culvert
# 20        N1     9.963  LRP010b  23.699861  90.530722         Culvert
# 21        N1    10.377  LRP010c  23.697416  90.533777         Culvert
# 22        N1    10.503   LRP011  23.696639  90.534805          KmPost
# 23        N1    10.885  LRP011a  23.694361  90.537611         Culvert
# 24        N1    11.313  LRP011b  23.692277  90.541055         Culvert
# 25        N1    11.497   LRP012  23.691805  90.542611          KmPost
# 26        N1    11.745  LRP012a  23.691111  90.544889          Bridge
# 27        N1    11.771  LRP012b  23.691055  90.545139          Bridge
# 28        N1    11.936  LRP012c  23.690416  90.546583  SideRoad,Right
# 29        N1    12.524   LRP013  23.686527  90.550417          KmPost
# ...      ...       ...      ...        ...        ...             ...
# 52180  Z8916     6.991   LRP007  22.611444  90.716056          KmPost
# 52181  Z8916     7.648  LRP007a  22.606167  90.715000       CrossRoad
# 52182  Z8916     7.991   LRP008  22.603750  90.717333          KmPost
# 52183  Z8916     8.991   LRP009  22.598444  90.724166          KmPost
# 52184  Z8916     9.754  LRP009a  22.595389  90.731110         Culvert
# 52185  Z8916     9.991   LRP010  22.595722  90.732916          KmPost
# 52186  Z8916    10.991   LRP011  22.595666  90.741472          KmPost
# 52183                                    Km Post missing  0.005306  0.006833
# 52184                                        Box Culvert  0.003055  0.006944
# 52185                                    Km Post missing  0.000333  0.001806
# 52186                                    Km Post missing  0.000056  0.008556
# 52187                                      Turn off left  0.000778  0.001583
# 52188                                     Turn off Right  0.001028  0.000056
# 52189      End at Selim Chattar at Intersect with Z8915.  0.000417  0.003667
# 52190  Start at intersection of Z8905 /BC joint infro...  0.000000  0.000000
# 52191                                        Box Culvert  0.000028  0.002639
# 52192                                    Km Post Missing  0.000972  0.006972
# 52193                                        Box Culvert  0.998972  0.000556
# 52194                                    Km Post Missing  0.998389  0.007695
# 52195                                        Box Culvert  0.001167  0.005139
# 52196                                    Km Post Missing  0.000028  0.004167
# 52197                                        Box Culvert  0.000444  0.003167
# 52198                                        Box Culvert  0.000750  0.005527
# 52199                                    Km Post Missing  0.000028  0.000472
# 52200                                    Km Post Missing  0.000917  0.009361
# 52201                                    Km Post Missing  0.003333  0.008973
# 52202                                 Z8948 to Khaserhat  0.002250  0.006389
# 52203                                    Start of Bridge  0.000056  0.000000
# 52204                                      End of Bridge  0.000083  0.000278
# 52205                                    Km Post Missing  0.000694  0.002417
# 52206                                    Km Post Missing  0.000611  0.009389
# 52207                                    Start of Bridge  0.000139  0.001445
# 52208                                      End of Bridge  0.000000  0.000028
# 52209  End at Kunjerhat Bazar and intersct with R890,...  0.000083  0.005944
#
#       delete_c
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 9         None
# 10        None
# 11        None
# 12        None
# 13        None
# 14        None
# 15        None
# 16        None
# 17        None
# 18        None
# 19        None
# 20        None
# 21        None
# 22        None
# 23        None
# 24        None
# 25        None
# 26        None
# 27        None
# 28        None
# 29        None
# ...        ...
# 52180     None
# 52181     None
# 52182     None
# 52183   delete
# 52184   delete
# 52185     None
# 52186   delete
# 52187     None
# 52188     None
# 52189     None
# 52190     None
# 52191     None
# 52192   delete
# 52193   delete
# 52194   delete
# 52195     None
# 52196     None
# 52197     None
# 52198     None
# 52199     None
# 52200   delete
# 52201   delete
# 52202     None
# 52203     None
# 52204     None
# 52205     None
# 52206   delete
# 52207     None
# 52208     None
# 52209     None
#
# [52210 rows x 10 columns]

# %%
#Simple solution to the outliers: delete the records which are classified as outliers.
df_roadsinfo = df_roadsinfo[df_roadsinfo["delete_c"] != "delete"]

# %%
df_roadsinfo = df_roadsinfo[["road", "chainage", "lrp", "lat", "lon", "type", "name"]]

df_roadsinfo.head()
# Out:
#   road  chainage     lrp        lat        lon       type  \
# 0   N1     0.000    LRPS  23.706028  90.443333     Others
# 1   N1     0.814   LRPSa  23.702917  90.450417    Culvert
# 2   N1     0.822   LRPSb  23.702778  90.450472  CrossRoad
# 3   N1     1.000  LRP001  23.702139  90.451972     KmPost
# 4   N1     2.000  LRP002  23.697889  90.460583     KmPost
#
#                                                 name
# 0  Start of Road  after Jatrabari Flyover infront...
# 1                                        Box Culvert
# 2                            Intersection with Z1101
# 3                                    Km post missing
# 4                                    Km post missing

# %%
#Convert to the CSV file. Save updated file under a new name. Remember to rename for the java program!
df_roadsinfo.to_csv('Roads_InfoAboutEachLRP_new.csv', index=False)

# %%
#Make a smaller version of the file in order to make it easier to use this data for the _roads.tcv file. 
df_small_roadsinfo = df_roadsinfo[["road", "lrp", "lat", "lon"]]
